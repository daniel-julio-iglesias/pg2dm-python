# %%
# Enables autoreload of your Python file if edited
# %load_ext autoreload
# %autoreload 2


# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
    
# from src.energy_forecaster import EnergyForecaster

# # Adds the src/ folder to your path
# import sys
# sys.path.append('src')

# Import your class
# from energy_forecaster import EnergyForecaster
from recommender import recommender
from recommender import users

# %%
users
# Out:
# {'Angelica': {'Blues Traveler': 3.5,
#   'Broken Bells': 2.0,
#   'Norah Jones': 4.5,
#   'Phoenix': 5.0,
#   'Slightly Stoopid': 1.5,
#   'The Strokes': 2.5,
#   'Vampire Weekend': 2.0},
#  'Bill': {'Blues Traveler': 2.0,
#   'Broken Bells': 3.5,
#   'Deadmau5': 4.0,
#   'Phoenix': 2.0,
#   'Slightly Stoopid': 3.5,
#   'Vampire Weekend': 3.0},
#  'Chan': {'Blues Traveler': 5.0,
#   'Broken Bells': 1.0,
#   'Deadmau5': 1.0,
#   'Norah Jones': 3.0,
#   'Phoenix': 5,
#   'Slightly Stoopid': 1.0},
#  'Dan': {'Blues Traveler': 3.0,
#   'Broken Bells': 4.0,
#   'Deadmau5': 4.5,
#   'Phoenix': 3.0,
#   'Slightly Stoopid': 4.5,
#   'The Strokes': 4.0,
#   'Vampire Weekend': 2.0},
#  'Hailey': {'Broken Bells': 4.0,
#   'Deadmau5': 1.0,
#   'Norah Jones': 4.0,
#   'The Strokes': 4.0,
#   'Vampire Weekend': 1.0},
#  'Jordyn': {'Broken Bells': 4.5,
#   'Deadmau5': 4.0,
#   'Norah Jones': 5.0,
#   'Phoenix': 5.0,
#   'Slightly Stoopid': 4.5,
#   'The Strokes': 4.0,
#   'Vampire Weekend': 4.0},
# ...

# %%
r = recommender(users)

# %%
r.recommend('Jordyn')
# Out:
# [('Blues Traveler', 5.0)]

# %%
r.recommend('Hailey')
# Out:
# [('Phoenix', 5.0), ('Slightly Stoopid', 4.5)]

# %%
r.loadBookDB('D:\\daniel\\JupyterProjects\\pg2dm\\data\\ch2\\BX-Dump\\')
# Out:
# 1700018

# %%
r.recommend('171118')
# Out:
# [("A Swiftly Tilting Planet by Madeleine L'Engle", 10.0),
#  ("The Godmother's Apprentice by Elizabeth Ann Scarborough", 10.0),
#  ("The Godmother's Web by Elizabeth Ann Scarborough", 10.0),
#  ("The Irrational Season (The Crosswicks Journal, Book 3) by Madeleine L'Engle",
#   10.0),
#  ('The Girl Who Loved Tom Gordon by Stephen King', 9.0)]

# %%
r.userRatings('171118', 5)
# Out:
# Ratings for toronto, ontario, canada
# 2421
# 0006479502	10
# Time Power: The Revolutionary Time Management System That Can Change Your Professional and Personal by Charles Hobbs	10
# Pilgrim at Tinker Creek by Annie Dillard	10
# 0099430967	10
# Just So Stories (Penguin Twentieth-Century Classics) by Rudyard Kipling	10
